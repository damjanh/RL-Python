# %% [markdown]
# # Import Dependencies

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %% [markdown]
# # Test Environment

# %%
env = gym.make('CarRacing-v2', render_mode='human')

# %%
env.reset()
env.render()

# %%
episodes = 1
for episode in range(1, episodes + 1):
    obs = env.reset()
    done = False
    score = 0
    while not done:
        env.render()
        action = env.action_space.sample()
        obs, reward, done, _, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 9
#       7     env.render()
#       8     action = env.action_space.sample()
# ----> 9     obs, reward, done, _, info = env.step(action)
#      10     score += reward
#      11 print('Episode:{} Score:{}'.format(episode, score))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\env_checker.py:49, in PassiveEnvChecker.step(self, action)
#      47     return env_step_passive_checker(self.env, action)
#      48 else:
# ---> 49     return self.env.step(action)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\box2d\car_racing.py:553, in CarRacing.step(self, action)
#     550 self.world.Step(1.0 / FPS, 6 * 30, 2 * 30)
#     551 self.t += 1.0 / FPS
# --> 553 self.state = self._render("state_pixels")
#     555 step_reward = 0
#     556 terminated = False
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\box2d\car_racing.py:617, in CarRacing._render(self, mode)
#     614 trans = pygame.math.Vector2((scroll_x, scroll_y)).rotate_rad(angle)
#     615 trans = (WINDOW_W / 2 + trans[0], WINDOW_H / 4 + trans[1])
# --> 617 self._render_road(zoom, trans, angle)
#     618 self.car.draw(
#     619     self.surf,
#     620     zoom,
#    (...)
#     623     mode not in ["state_pixels_list", "state_pixels"],
#     624 )
#     626 self.surf = pygame.transform.flip(self.surf, False, True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\box2d\car_racing.py:678, in CarRacing._render_road(self, zoom, translation, angle)
#     669         grass.append(
#     670             [
#     671                 (GRASS_DIM * x + GRASS_DIM, GRASS_DIM * y + 0),
#    (...)
#     675             ]
#     676         )
#     677 for poly in grass:
# --> 678     self._draw_colored_polygon(
#     679         self.surf, poly, self.grass_color, zoom, translation, angle
#     680     )
#     682 # draw road
#     683 for poly, color in self.road_poly:
#     684     # converting to pixel coordinates
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\box2d\car_racing.py:775, in CarRacing._draw_colored_polygon(self, surface, poly, color, zoom, translation, angle, clip)
#     769 if not clip or any(
#     770     (-MAX_SHAPE_DIM <= coord[0] <= WINDOW_W + MAX_SHAPE_DIM)
#     771     and (-MAX_SHAPE_DIM <= coord[1] <= WINDOW_H + MAX_SHAPE_DIM)
#     772     for coord in poly
#     773 ):
#     774     gfxdraw.aapolygon(self.surf, poly, color)
# --> 775     gfxdraw.filled_polygon(self.surf, poly, color)
#
# KeyboardInterrupt:

# %%
env.close()

# %% [markdown]
# # Train Model

# %%
env = gym.make('CarRacing-v2')
env = DummyVecEnv([lambda: env])

# %%
log_path = os.path.join('Training', 'Logs')
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 log_path = os.path.join('Training', 'Logs')
# ----> 2 model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=log_path)
#
# NameError: name 'env' is not defined

# %%
model.learn(total_timesteps=100000)
# Out:
# Logging to Training\Logs\PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 31   |
# |    iterations      | 1    |
# |    time_elapsed    | 65   |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 23           |
# |    iterations           | 2            |
# |    time_elapsed         | 175          |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0076060225 |
# |    clip_fraction        | 0.0737       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | 0.0124       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.16         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00766     |
# |    std                  | 0.992        |
# |    value_loss           | 0.624        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 3           |
# |    time_elapsed         | 286         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008217176 |
# |    clip_fraction        | 0.0795      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.164       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.16        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00827    |
# |    std                  | 0.985       |
# |    value_loss           | 0.526       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 4           |
# |    time_elapsed         | 406         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009204777 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | 0.115       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.127       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.971       |
# |    value_loss           | 0.459       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 5           |
# |    time_elapsed         | 524         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013000233 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.316       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.178       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.964       |
# |    value_loss           | 0.428       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 6           |
# |    time_elapsed         | 650         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012682516 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.142       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 0.961       |
# |    value_loss           | 0.488       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 7           |
# |    time_elapsed         | 773         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010333211 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.175       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0648      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0149     |
# |    std                  | 0.951       |
# |    value_loss           | 0.482       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 8           |
# |    time_elapsed         | 898         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.019915638 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.261       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.172       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0221     |
# |    std                  | 0.944       |
# |    value_loss           | 0.358       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 9           |
# |    time_elapsed         | 1014        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.016986765 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.101       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.123       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0226     |
# |    std                  | 0.936       |
# |    value_loss           | 0.414       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 10          |
# |    time_elapsed         | 1149        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.016937159 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.04       |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0297      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0235     |
# |    std                  | 0.923       |
# |    value_loss           | 0.34        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 11          |
# |    time_elapsed         | 1277        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.020615261 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.119       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0253     |
# |    std                  | 0.911       |
# |    value_loss           | 0.392       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 12          |
# |    time_elapsed         | 1407        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.020055044 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0113     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.902       |
# |    value_loss           | 0.215       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 13          |
# |    time_elapsed         | 1525        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.018169107 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.93       |
# |    explained_variance   | 0.824       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0375      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0192     |
# |    std                  | 0.893       |
# |    value_loss           | 0.142       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 14          |
# |    time_elapsed         | 1648        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.019453049 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.89       |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0437      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0239     |
# |    std                  | 0.883       |
# |    value_loss           | 0.169       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 15          |
# |    time_elapsed         | 1771        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.025578842 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | 0.8         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0334     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.024      |
# |    std                  | 0.868       |
# |    value_loss           | 0.265       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 16          |
# |    time_elapsed         | 1888        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.019549357 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.8        |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000353    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.858       |
# |    value_loss           | 0.175       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 17          |
# |    time_elapsed         | 2016        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.021866767 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.77       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00946    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0261     |
# |    std                  | 0.847       |
# |    value_loss           | 0.259       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 18          |
# |    time_elapsed         | 2140        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.021688594 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.74       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.015      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0272     |
# |    std                  | 0.842       |
# |    value_loss           | 0.329       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 19         |
# |    time_elapsed         | 2267       |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.02701884 |
# |    clip_fraction        | 0.241      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.72      |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0151     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0281    |
# |    std                  | 0.837      |
# |    value_loss           | 0.271      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 20          |
# |    time_elapsed         | 2394        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.027538208 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00173    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0352     |
# |    std                  | 0.823       |
# |    value_loss           | 0.317       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 21          |
# |    time_elapsed         | 2516        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.028909294 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0655      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0326     |
# |    std                  | 0.807       |
# |    value_loss           | 0.545       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 22          |
# |    time_elapsed         | 2645        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.031465534 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.101       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0348     |
# |    std                  | 0.801       |
# |    value_loss           | 0.468       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 23          |
# |    time_elapsed         | 2777        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.038528938 |
# |    clip_fraction        | 0.322       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.79        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0415      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0357     |
# |    std                  | 0.788       |
# |    value_loss           | 0.499       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 24          |
# |    time_elapsed         | 2899        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.052821018 |
# |    clip_fraction        | 0.328       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.49       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0489      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.038      |
# |    std                  | 0.775       |
# |    value_loss           | 0.6         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 25          |
# |    time_elapsed         | 3021        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.030880101 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.45       |
# |    explained_variance   | 0.839       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.43        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0214     |
# |    std                  | 0.769       |
# |    value_loss           | 0.685       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 26          |
# |    time_elapsed         | 3135        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.028474532 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.105       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0257     |
# |    std                  | 0.757       |
# |    value_loss           | 0.814       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 27         |
# |    time_elapsed         | 3250       |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.04939338 |
# |    clip_fraction        | 0.316      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.37      |
# |    explained_variance   | 0.775      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.281      |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.029     |
# |    std                  | 0.75       |
# |    value_loss           | 1.45       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 28          |
# |    time_elapsed         | 3367        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.039589643 |
# |    clip_fraction        | 0.322       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.35       |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.322       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0289     |
# |    std                  | 0.745       |
# |    value_loss           | 1.32        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 29         |
# |    time_elapsed         | 3497       |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.09279815 |
# |    clip_fraction        | 0.436      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.32      |
# |    explained_variance   | 0.872      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0719     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0345    |
# |    std                  | 0.739      |
# |    value_loss           | 0.744      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 30         |
# |    time_elapsed         | 3634       |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.06152721 |
# |    clip_fraction        | 0.353      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.3       |
# |    explained_variance   | 0.82       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.182      |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0245    |
# |    std                  | 0.732      |
# |    value_loss           | 1          |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 31         |
# |    time_elapsed         | 3772       |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.04123152 |
# |    clip_fraction        | 0.361      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.27      |
# |    explained_variance   | 0.83       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.369      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0222    |
# |    std                  | 0.723      |
# |    value_loss           | 1.6        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 32         |
# |    time_elapsed         | 3886       |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.05081944 |
# |    clip_fraction        | 0.344      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.23      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.102      |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0197    |
# |    std                  | 0.716      |
# |    value_loss           | 0.798      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 33         |
# |    time_elapsed         | 3999       |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.04823628 |
# |    clip_fraction        | 0.349      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.21      |
# |    explained_variance   | 0.761      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.128      |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0295    |
# |    std                  | 0.709      |
# |    value_loss           | 0.941      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 34          |
# |    time_elapsed         | 4112        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.047290314 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.434       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0225     |
# |    std                  | 0.709       |
# |    value_loss           | 1.1         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 35         |
# |    time_elapsed         | 4225       |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.06298705 |
# |    clip_fraction        | 0.374      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.15      |
# |    explained_variance   | 0.789      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.186      |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0271    |
# |    std                  | 0.696      |
# |    value_loss           | 0.869      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 36          |
# |    time_elapsed         | 4337        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.103252694 |
# |    clip_fraction        | 0.412       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.12       |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.202       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0314     |
# |    std                  | 0.694       |
# |    value_loss           | 1.01        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 37         |
# |    time_elapsed         | 4451       |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.04825235 |
# |    clip_fraction        | 0.396      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.1       |
# |    explained_variance   | 0.773      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.208      |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0194    |
# |    std                  | 0.687      |
# |    value_loss           | 0.921      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 38          |
# |    time_elapsed         | 4565        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.049222194 |
# |    clip_fraction        | 0.35        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 0.79        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.226       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0216     |
# |    std                  | 0.684       |
# |    value_loss           | 1.39        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 39          |
# |    time_elapsed         | 4677        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.057010654 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.098       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.678       |
# |    value_loss           | 1.19        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 40         |
# |    time_elapsed         | 4760       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.06973289 |
# |    clip_fraction        | 0.407      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.02      |
# |    explained_variance   | 0.913      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.112      |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0127    |
# |    std                  | 0.676      |
# |    value_loss           | 0.718      |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 17        |
# |    iterations           | 41        |
# |    time_elapsed         | 4842      |
# |    total_timesteps      | 83968     |
# | train/                  |           |
# |    approx_kl            | 0.0556819 |
# |    clip_fraction        | 0.386     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.01     |
# |    explained_variance   | 0.942     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.301     |
# |    n_updates            | 400       |
# |    policy_gradient_loss | -0.0113   |
# |    std                  | 0.672     |
# |    value_loss           | 1.32      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 42          |
# |    time_elapsed         | 4923        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.055253826 |
# |    clip_fraction        | 0.396       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.289       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.669       |
# |    value_loss           | 1.95        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 43         |
# |    time_elapsed         | 5005       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.05509696 |
# |    clip_fraction        | 0.425      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.98      |
# |    explained_variance   | 0.845      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.488      |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.024     |
# |    std                  | 0.669      |
# |    value_loss           | 3.96       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 44         |
# |    time_elapsed         | 5086       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.04992763 |
# |    clip_fraction        | 0.398      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.97      |
# |    explained_variance   | 0.861      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.793      |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.00881   |
# |    std                  | 0.669      |
# |    value_loss           | 5.07       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 45         |
# |    time_elapsed         | 5167       |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.08153966 |
# |    clip_fraction        | 0.469      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.97      |
# |    explained_variance   | 0.87       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.55       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0119    |
# |    std                  | 0.667      |
# |    value_loss           | 6.18       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 46         |
# |    time_elapsed         | 5247       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.06606415 |
# |    clip_fraction        | 0.44       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.96      |
# |    explained_variance   | 0.858      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.286      |
# |    n_updates            | 450        |
# |    policy_gradient_loss | 0.00284    |
# |    std                  | 0.665      |
# |    value_loss           | 4.26       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 47          |
# |    time_elapsed         | 5327        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.060289234 |
# |    clip_fraction        | 0.419       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.364       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00996    |
# |    std                  | 0.661       |
# |    value_loss           | 2.4         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 18         |
# |    iterations           | 48         |
# |    time_elapsed         | 5407       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.05077721 |
# |    clip_fraction        | 0.38       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.93      |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.346      |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.00913   |
# |    std                  | 0.657      |
# |    value_loss           | 3.69       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 18         |
# |    iterations           | 49         |
# |    time_elapsed         | 5488       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.05549266 |
# |    clip_fraction        | 0.404      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.92      |
# |    explained_variance   | 0.949      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.393      |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0051    |
# |    std                  | 0.657      |
# |    value_loss           | 4.34       |
# ----------------------------------------

# %% [markdown]
# # Save Model

# %%
ppo_path = os.path.join('Training', 'Saved Models', 'PPO_Driving_Model')

# %%
model.save(ppo_path)

# %%
del model

# %%
model = PPO.load(ppo_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# # Evaluate and Test

# %%
evaluate_policy(model, env, n_eval_episodes=5, render=False)
# Out:
# (37.804464916884896, 127.30278538192658)

# %%
env = gym.make('CarRacing-v2', render_mode='human')
env = DummyVecEnv([lambda: env])

# %%
episodes = 5
for episode in range(1, episodes + 1):
    obs = env.reset()
    done = False
    score = 0
    while not done:
        env.render()
        action, _ = model.predict(obs) # Using model
        obs, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# Episode:1 Score:[234.43301]
# Episode:2 Score:[82.129234]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 9
#       7     env.render()
#       8     action, _ = model.predict(obs) # Using model
# ----> 9     obs, reward, done, info = env.step(action)
#      10     score += reward
#      11 print('Episode:{} Score:{}'.format(episode, score))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:188, in VecEnv.step(self, actions)
#     181 """
#     182 Step the environments with the given action
#     183
#     184 :param actions: the action
#     185 :return: observation, reward, done, information
#     186 """
#     187 self.step_async(actions)
# --> 188 return self.step_wait()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\env_checker.py:49, in PassiveEnvChecker.step(self, action)
#      47     return env_step_passive_checker(self.env, action)
#      48 else:
# ---> 49     return self.env.step(action)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\box2d\car_racing.py:553, in CarRacing.step(self, action)
#     550 self.world.Step(1.0 / FPS, 6 * 30, 2 * 30)
#     551 self.t += 1.0 / FPS
# --> 553 self.state = self._render("state_pixels")
#     555 step_reward = 0
#     556 terminated = False
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\box2d\car_racing.py:617, in CarRacing._render(self, mode)
#     614 trans = pygame.math.Vector2((scroll_x, scroll_y)).rotate_rad(angle)
#     615 trans = (WINDOW_W / 2 + trans[0], WINDOW_H / 4 + trans[1])
# --> 617 self._render_road(zoom, trans, angle)
#     618 self.car.draw(
#     619     self.surf,
#     620     zoom,
#    (...)
#     623     mode not in ["state_pixels_list", "state_pixels"],
#     624 )
#     626 self.surf = pygame.transform.flip(self.surf, False, True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\box2d\car_racing.py:687, in CarRacing._render_road(self, zoom, translation, angle)
#     685 poly = [(p[0], p[1]) for p in poly]
#     686 color = [int(c) for c in color]
# --> 687 self._draw_colored_polygon(self.surf, poly, color, zoom, translation, angle)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\box2d\car_racing.py:774, in CarRacing._draw_colored_polygon(self, surface, poly, color, zoom, translation, angle, clip)
#     764 # This checks if the polygon is out of bounds of the screen, and we skip drawing if so.
#     765 # Instead of calculating exactly if the polygon and screen overlap,
#     766 # we simply check if the polygon is in a larger bounding box whose dimension
#     767 # is greater than the screen by MAX_SHAPE_DIM, which is the maximum
#     768 # diagonal length of an environment object
#     769 if not clip or any(
#     770     (-MAX_SHAPE_DIM <= coord[0] <= WINDOW_W + MAX_SHAPE_DIM)
#     771     and (-MAX_SHAPE_DIM <= coord[1] <= WINDOW_H + MAX_SHAPE_DIM)
#     772     for coord in poly
#     773 ):
# --> 774     gfxdraw.aapolygon(self.surf, poly, color)
#     775     gfxdraw.filled_polygon(self.surf, poly, color)
#
# KeyboardInterrupt:
